# %%
#installing selenium library
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: six>=1.5.2 in c:\users\hp\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import NoSuchElementException

# %%
#controlling the edge browser
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
#exercise 1 : open amazon and search for a product
url = 'https://www.amazon.in/'
driver.get(url)

# %%
driver.maximize_window()

# %%
search_box = driver.find_element_by_xpath('//input[@class="nav-input nav-progressive-attribute"]')

# %%
search_box.send_keys('books')

# %%
search_btn = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]')

# %%
search_btn.click()

# %%
#exercise 2 - now scrape the data for books on amazon
import time

# %%
 #Make empty lists
Brand = []   
Name = []
Rating = []
no_of_ratings = []
Price = []
Return = []
expected_delivery = []
Availability = [] 
Other_Details = []

# %%
start=0
end=3

# %%
driver.get(url)
time.sleep(2)
    
 # Extracting Brand from xpath
try:
    brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')      
    Brand.append(brand.text)
except NoSuchElementException:
    Brand.append('-')    


time.sleep(1)# Extracting name from id
try:
    name = driver.find_element_by_id('productTitle')      
    Name.append(name.text)
except NoSuchElementException:
    Name.append('-')
    time.sleep(1)    
    # Extracting Ratings from xpath    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    # Extracting No of Ratings from xpath
    try:
        no_rating = driver.find_element_by_id('acrCustomerReviewText')  
        no_of_ratings.append(no_rating.text)
    except NoSuchElementException:
        no_of_ratings.append('-')


    time.sleep(1)
    # Extracting price from xpath    
    try:
        price = driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')


    time.sleep(1)
    # Extracting Return from xpath
    try:
        return_ = driver.find_element_by_xpath('//a[@class="a-size-small a-link-normal a-text-normal"]')  
        Return.append(return_.text)
    except NoSuchElementException:
        Return.append('-')


    time.sleep(1)
    # Extracting expected_delivery from xpath
    try:
        exptd_dlvry= driver.find_element_by_xpath('//span[@class="a-color-error"]')  
        expected_delivery.append(exptd_dlvry.text)
    except NoSuchElementException:
         expected_delivery.append('-')


    time.sleep(1)
    # Extracting Availability from xpath         
    try:
        avl= driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')  
        Availability.append(avl.text)
    except NoSuchElementException:
        Availability.append('-')



    time.sleep(1)
    # Extracting Other Details from xpath    
    try:
        othr_dtls= driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')  
        Other_Details.append(othr_dtls.text)
    except NoSuchElementException:
        Other_Details.append('-')

time.sleep(2)    
# Make dataframe
prod_df = pd.DataFrame({'Brand':Brand,'Name':Name,'Rating':Rating,'No. of ratings':no_of_ratings,'Price':Price,
                        'Return/Exchange':Return,'Expected Delivery':expected_delivery,'Availability':Availability,
                        'Other Details':Other_Details})
prod_df.head(5)
# Out:
#   Brand Name Rating No. of ratings Price Return/Exchange Expected Delivery  \
# 0     -    -      -              -     -               -                 -
#
#   Availability Other Details
# 0            -             -

# %%
#Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#installing selenium library
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: six>=1.5.2 in c:\users\hp\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import NoSuchElementException

# %%
#controlling the edge browser
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
#exercise 1 : open google and search for a product
url = 'https://images.google.com/'
driver.get(url)

# %%
driver.maximize_window()

# %%
search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("fruits")       # Inputing "fruits" keyword to search images
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Finding the xpath of search button
search_button.click()

# %%
import requests

# %%
for _ in range(10):
    images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"D:\Brijesh\Internship\websrape 3"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %%
#installing selenium library
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: six>=1.5.2 in c:\users\hp\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import NoSuchElementException

# %%
#exercise 1 : open google and search for a product
url = 'https://images.google.com/'
driver.get(url)

# %%
driver.maximize_window()

# %%
search_bar = driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
search_bar.send_keys("cars")

# %%
search_btn = driver.find_element_by_xpath('//span[@class="z1asCe MZy1Rb"]')
search_btn.click()

# %%
images = driver.find_elements_by_xpath('//div[@class="bRMDJf islir"]')
image_urls = []
image_data = []
for image in images:
    source = image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"D:\Brijesh\Internship\websrape 3"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images

# %% [markdown]
# 4- Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#installing selenium library
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: trio~=0.17 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: outcome in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\hp\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\hp\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: six>=1.5.2 in c:\users\hp\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import NoSuchElementException
import time

# %%
#controlling the edge browser
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
#exercise 1 : open google and search for a product
url = 'http://www.flipkart.com/'
driver.get(url)

# %%
click_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()
#giving inputs to search bar
search_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
search_bar.send_keys("Smartphones")
search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn.click()
time.sleep(3)

# %%
# fetching urls of every smartphone on Flipkart
urls = []
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

# getting the required data inside the empty lists
brand_names = []
name = []
color = []
RAM = []
storage = []
prim_cam = []
sec_cam = []
Display_size = []
display_resolution = []
processor = []
processor_core = []
battery_cap = []
prices = []
product_url = []

# fetching battery capacity
for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
    try:
        bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
        battery_cap.append(bat_cap.text)
    except NoSuchElementException:
        battery_cap.append('-')
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    # fetching brand names
    try:
        br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        brand_names.append(br_name.text.replace('Mobiles',''))
    except NoSuchElementException:
        brand_names.append('-')
    # fetching the smartphone names
    try:
        smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
        name.append(smt_name.text)
    except NoSuchElementException:
        name.append('-')
    
    # fetching colors of smartphone
    try:
        clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
        color.append(clr.text)
    except NoSuchElementException:
        color.append('-')
    time.sleep(2)
    
    # getting the read more button
    try:
        read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    except NoSuchElementException:
        pass
    time.sleep(3)
    
    # fetching the display size
    try:
        disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
        Display_size.append(disp_size.text)
    except NoSuchElementException:
        Display_size.append
        
    # fetching the display resolution
    try:
        disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
        display_resolution.append(disp_res.text)
    except NoSuchElementException:
        display_resolution.append('-')
        
    # fetching the processor information
    try:
        pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
        processor.append(pro.text)
    except NoSuchElementException:
        processor.append('-')
        
    # fetching the processor and number of core details
    try:
        pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
        processor_core.append(pro_core.text)
    except NoSuchElementException:
        processor_core.append('-')
        
    # fetching the storage/ROM details
    try:
        rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
        storage.append(rom.text)
    except NoSuchElementException:
        storage.append('-')
        
    # fetching the RAM information
    try:
        ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    time.sleep(2)
    
    # fetching the primary camera information
    try:
        p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
        prim_cam.append(p_cam.text)
    except NoSuchElementException:
        prim_cam.append('-')
        
    # fetching the secondary camera information
    try:
        s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
        sec_cam.append(s_cam.text)
    except NoSuchElementException:
        sec_cam.append('-')        
   
    # fetching the price of the smartphone
    try:
        price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        prices.append(price.text.replace('₹','Rs. '))
    except NoSuchElementException:
        prices.append('-')
    
    
# creating a dataframe now with the obtainined details
data = list(zip(brand_names,name,color,RAM,storage,prim_cam,sec_cam,Display_size,display_resolution,processor,
                processor_core,battery_cap,prices,urls))
df = pd.DataFrame(data, columns = ["Brand Name","Smartphone Name","Color","RAM","Storage/ROM","Primary Camera",
                                   "Secondary Camera","Display Size","Display Resolution","Processor","Processor-Core",
                                   "Battery Capacity","Price","Product Url"])
df
# Out:
#    Brand Name                                    Smartphone Name  \
# 0      REDMI   REDMI 9i Sport (Metallic Blue, 64 GB)  (4 GB RAM)
# 1       POCO            POCO C31 (Royal Blue, 64 GB)  (4 GB RAM)
# 2    Infinix      Infinix Hot 11S (7° Purple, 64 GB)  (4 GB RAM)
# 3      REDMI     REDMI 9i Sport (Coral Green, 64 GB)  (4 GB RAM)
# 4    Infinix    Infinix Hot 11S (Polar Black, 64 GB)  (4 GB RAM)
# 5     realme   realme Narzo 50A (Oxygen Green, 128 GB)  (4 GB...
# 6     realme   realme Narzo 50A (Oxygen Blue, 64 GB)  (4 GB RAM)
# 7       vivo    vivo T1 5G (Rainbow Fantasy, 128 GB)  (4 GB RAM)
# 8       vivo    vivo T1 5G (Starlight Black, 128 GB)  (4 GB RAM)
# 9    Infinix    Infinix Hot 11S (Silver Wave, 64 GB)  (4 GB RAM)
# 10   Infinix     Infinix Hot 11S (Green Wave, 64 GB)  (4 GB RAM)
# 11    realme           realme C20 (Cool Grey, 32 GB)  (2 GB RAM)
# 12    realme   realme Narzo 50A (Oxygen Blue, 128 GB)  (4 GB ...
# 13    realme           realme C20 (Cool Blue, 32 GB)  (2 GB RAM)
# 14   Infinix   Infinix Hot 11S (Silver Wave, 128 GB)  (4 GB RAM)
# 15   Infinix   Infinix Hot 11S (Polar Black, 128 GB)  (4 GB RAM)
# 16   Infinix     Infinix Hot 11S (7° Purple, 128 GB)  (4 GB RAM)
# 17    realme   realme Narzo 50A (Oxygen Green, 64 GB)  (4 GB ...
# 18  MOTOROLA   MOTOROLA E7 Power (Tahiti Blue, 64 GB)  (4 GB ...
# 19      POCO           POCO C31 (Shadow Gray, 64 GB)  (4 GB RAM)
# 20      vivo    vivo T1 5G (Rainbow Fantasy, 128 GB)  (6 GB RAM)
# 21      vivo    vivo T1 5G (Starlight Black, 128 GB)  (6 GB RAM)
# 22  MOTOROLA   MOTOROLA G60 (Frosted Champagne, 128 GB)  (6 G...
# 23     REDMI    REDMI 9i Sport (Carbon Black, 64 GB)  (4 GB RAM)
#
#                 Color                 RAM Storage/ROM          Primary Camera  \
# 0       Metallic Blue                4 GB       64 GB        13MP Rear Camera
# 1          Royal Blue                4 GB       64 GB        13MP + 2MP + 2MP
# 2           7° Purple                4 GB       64 GB    50MP + 2MP + AI Lens
# 3         Coral Green                4 GB       64 GB        13MP Rear Camera
# 4         Polar Black                4 GB       64 GB    50MP + 2MP + AI Lens
# 5        Oxygen Green                4 GB      128 GB        50MP + 2MP + 2MP
# 6         Oxygen Blue                4 GB       64 GB        50MP + 2MP + 2MP
# 7     Rainbow Fantasy                4 GB      128 GB        50MP + 2MP + 2MP
# 8     Starlight Black                4 GB      128 GB        50MP + 2MP + 2MP
# 9         Silver Wave                4 GB       64 GB  50 MP + 2 MP + AI Lens
# 10         Green Wave                4 GB       64 GB    50MP + 2MP + AI Lens
# 11          Cool Grey  MediaTek Helio G35  Android 10                    2 GB
# 12        Oxygen Blue                4 GB      128 GB        50MP + 2MP + 2MP
# 13          Cool Blue  MediaTek Helio G35  Android 10                    2 GB
# 14        Silver Wave                4 GB      128 GB  50 MP + 2 MP + AI Lens
# 15        Polar Black                4 GB      128 GB  50 MP + 2 MP + AI Lens
# 16          7° Purple                4 GB      128 GB  50 MP + 2 MP + AI Lens
# 17       Oxygen Green                4 GB       64 GB        50MP + 2MP + 2MP
# 18        Tahiti Blue                4 GB       64 GB              13MP + 2MP
# 19        Shadow Gray                4 GB       64 GB        13MP + 2MP + 2MP
# 20    Rainbow Fantasy                6 GB      128 GB        50MP + 2MP + 2MP
# 21    Starlight Black                6 GB      128 GB        50MP + 2MP + 2MP
# 22  Frosted Champagne                6 GB      128 GB       108MP + 8MP + 2MP
# 23       Carbon Black                4 GB       64 GB        13MP Rear Camera
#
#      Secondary Camera                                       Display Size  \
# 0    5MP Front Camera                               16.59 cm (6.53 inch)
# 1    5MP Front Camera                               16.59 cm (6.53 inch)
# 2    8MP Front Camera                               17.22 cm (6.78 inch)
# 3    5MP Front Camera                               16.59 cm (6.53 inch)
# 4    8MP Front Camera                               17.22 cm (6.78 inch)
# 5    8MP Front Camera                                16.51 cm (6.5 inch)
# 6    8MP Front Camera                                16.51 cm (6.5 inch)
# 7   16MP Front Camera                               16.71 cm (6.58 inch)
# 8   16MP Front Camera                               16.71 cm (6.58 inch)
# 9    8MP Front Camera                               17.22 cm (6.78 inch)
# 10   8MP Front Camera                               17.22 cm (6.78 inch)
# 11     Dedicated Slot  Handset, Adapter (5V/2A), USB Cable, SIM Card ...
# 12   8MP Front Camera                                16.51 cm (6.5 inch)
# 13     Dedicated Slot  Handset, Adapter (5V/2A), USB Cable, SIM Card ...
# 14   8MP Front Camera                               17.22 cm (6.78 inch)
# 15   8MP Front Camera                               17.22 cm (6.78 inch)
# 16   8MP Front Camera                               17.22 cm (6.78 inch)
# 17   8MP Front Camera                                16.51 cm (6.5 inch)
# 18   5MP Front Camera                               16.54 cm (6.51 inch)
# 19   5MP Front Camera                               16.59 cm (6.53 inch)
# 20  16MP Front Camera                               16.71 cm (6.58 inch)
# 21  16MP Front Camera                               16.71 cm (6.58 inch)
# 22  32MP Front Camera                               17.22 cm (6.78 inch)
# 23   5MP Front Camera                               16.59 cm (6.53 inch)
#
#     Display Resolution                 Processor Processor-Core  \
# 0    1600 x 720 Pixels        MediaTek Helio G25      Octa Core
# 1    1600 x 720 Pixels        MediaTek Helio G35      Octa Core
# 2   2480 x 1080 Pixels        MediaTek Helio G88      Octa Core
# 3    1600 x 720 Pixels        MediaTek Helio G25      Octa Core
# 4   2480 x 1080 Pixels        MediaTek Helio G88      Octa Core
# 5    1600 x 720 Pixels        MediaTek Helio G85      Octa Core
# 6    1600 x 720 Pixels        MediaTek Helio G85      Octa Core
# 7   2408 x 1080 Pixels   Qualcomm Snapdragon 695      Octa Core
# 8   2408 x 1080 Pixels   Qualcomm Snapdragon 695      Octa Core
# 9   2480 x 1080 Pixels        Mediatek Helio G88      Octa Core
# 10  2480 x 1080 Pixels        MediaTek Helio G88      Octa Core
# 11   RMX3063 / RMX3061         1600 x 720 Pixels            HD+
# 12   1600 x 720 Pixels        MediaTek Helio G85      Octa Core
# 13   RMX3063 / RMX3061         1600 x 720 Pixels            HD+
# 14  2480 x 1080 Pixels        Mediatek Helio G88      Octa Core
# 15  2480 x 1080 Pixels        Mediatek Helio G88      Octa Core
# 16  2480 x 1080 Pixels        Mediatek Helio G88      Octa Core
# 17   1600 x 720 Pixels        MediaTek Helio G85      Octa Core
# 18   1600 x 720 Pixels        MediaTek Helio G25      Octa Core
# 19   1600 x 720 Pixels        MediaTek Helio G35      Octa Core
# 20  2408 x 1080 Pixels   Qualcomm Snapdragon 695      Octa Core
# 21  2408 x 1080 Pixels   Qualcomm Snapdragon 695      Octa Core
# 22  2460 x 1080 Pixels  Qualcomm Snapdragon 732G      Octa Core
# 23   1600 x 720 Pixels        MediaTek Helio G25      Octa Core
#
#                Battery Capacity       Price  \
# 0   5000 mAh Li-Polymer Battery   Rs. 8,999
# 1   5000 mAh Li-Polymer Battery   Rs. 9,499
# 2   5000 mAh Li-Polymer Battery  Rs. 10,999
# 3   5000 mAh Li-Polymer Battery   Rs. 8,999
# 4   5000 mAh Li-Polymer Battery  Rs. 10,999
# 5   5000 mAh Li-Polymer Battery  Rs. 12,549
# 6   5000 mAh Li-Polymer Battery  Rs. 11,549
# 7   5000 mAh Li-Polymer Battery  Rs. 15,990
# 8   5000 mAh Li-Polymer Battery  Rs. 15,990
# 9   5000 mAh Li-Polymer Battery  Rs. 10,999
# 10  5000 mAh Li-Polymer Battery  Rs. 10,999
# 11  5000 mAh Li-Polymer Battery   Rs. 7,499
# 12  5000 mAh Li-Polymer Battery  Rs. 12,549
# 13  5000 mAh Li-Polymer Battery   Rs. 7,499
# 14  5000 mAh Li-Polymer Battery  Rs. 11,999
# 15  5000 mAh Li-Polymer Battery  Rs. 11,999
# 16  5000 mAh Li-Polymer Battery  Rs. 11,999
# 17  5000 mAh Li-Polymer Battery  Rs. 11,549
# 18  5000 mAh Li-Polymer Battery   Rs. 9,049
# 19  5000 mAh Li-Polymer Battery   Rs. 9,499
# 20  5000 mAh Li-Polymer Battery  Rs. 16,990
# 21  5000 mAh Li-Polymer Battery  Rs. 16,990
# 22  5000 mAh Li-Polymer Battery  Rs. 17,999
# 23  5000 mAh Li-Polymer Battery   Rs. 8,999
#
#                                           Product Url
# 0   https://www.flipkart.com/redmi-9i-sport-metall...
# 1   https://www.flipkart.com/poco-c31-royal-blue-6...
# 2   https://www.flipkart.com/infinix-hot-11s-7-pur...
# 3   https://www.flipkart.com/redmi-9i-sport-coral-...
# 4   https://www.flipkart.com/infinix-hot-11s-polar...
# 5   https://www.flipkart.com/realme-narzo-50a-oxyg...
# 6   https://www.flipkart.com/realme-narzo-50a-oxyg...
# 7   https://www.flipkart.com/vivo-t1-5g-rainbow-fa...
# 8   https://www.flipkart.com/vivo-t1-5g-starlight-...
# 9   https://www.flipkart.com/infinix-hot-11s-silve...
# 10  https://www.flipkart.com/infinix-hot-11s-green...
# 11  https://www.flipkart.com/realme-c20-cool-grey-...
# 12  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 13  https://www.flipkart.com/realme-c20-cool-blue-...
# 14  https://www.flipkart.com/infinix-hot-11s-silve...
# 15  https://www.flipkart.com/infinix-hot-11s-polar...
# 16  https://www.flipkart.com/infinix-hot-11s-7-pur...
# 17  https://www.flipkart.com/realme-narzo-50a-oxyg...
# 18  https://www.flipkart.com/motorola-e7-power-tah...
# 19  https://www.flipkart.com/poco-c31-shadow-gray-...
# 20  https://www.flipkart.com/vivo-t1-5g-rainbow-fa...
# 21  https://www.flipkart.com/vivo-t1-5g-starlight-...
# 22  https://www.flipkart.com/motorola-g60-frosted-...
# 23  https://www.flipkart.com/redmi-9i-sport-carbon...

# %%
# obtaining the web page with the provided url
url='https://www.google.co.in/maps'
driver.get(url)
srch_box = driver.find_element_by_class_name("tactile-searchbox-input")  # getting the search bar
place = str(input("Enter the place name which you want to search on Google Maps: "))  # taking input from user to search for location
srch_box.send_keys(place)    
submit = driver.find_element_by_class_name("searchbox-searchbutton").click()  # clicking on the search button
current_url = driver.current_url   # coordinates are presents in the URL so fetching current url

import re

try:
    lat = re.findall('(\d+(\.\d*)?)', current_url)[0]   # fetching the latitude data
    lon = re.findall('(\d+(\.\d*)?)', current_url)[1]  # fetching the longitude data
    print("Geospatial Coordinates for", place + " on Google Maps are: ")
    print("Latitude  :", lat[0])
    print("Longitude :", lon[0])
    time.sleep(3)
except Exception as e:
    print("Error: ", str(e))
# Out:
# Enter the place name which you want to search on Google Maps: noida
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-9-610347477736> in <module>
#       5 place = str(input("Enter the place name which you want to search on Google Maps: "))  # taking input from user to search for location
#       6 srch_box.send_keys(place)
# ----> 7 submit = driver.find_element_by_class_name("searchbox-searchbutton").click()  # clicking on the search button
#       8 current_url = driver.current_url   # coordinates are presents in the URL so fetching current url
#       9
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     758             stacklevel=2,
#     759         )
# --> 760         return self.find_element(by=By.CLASS_NAME, value=name)
#     761
#     762     def find_elements_by_class_name(self, name) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".searchbox-searchbutton"}
#   (Session info: MicrosoftEdge=99.0.1150.36)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x00007FF772263A82+22610]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7721A2352+503810]
# 	Ordinal0 [0x00007FF771CA0FA5+659365]
# 	Ordinal0 [0x00007FF771CDBF82+900994]
# 	Ordinal0 [0x00007FF771CDC258+901720]
# 	Ordinal0 [0x00007FF771D0E1A7+1106343]
# 	Ordinal0 [0x00007FF771CF707F+1011839]
# 	Ordinal0 [0x00007FF771D0B8A4+1095844]
# 	Ordinal0 [0x00007FF771CF6E53+1011283]
# 	Ordinal0 [0x00007FF771CCE0C7+843975]
# 	Ordinal0 [0x00007FF771CCF598+849304]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF771E691B8+848488]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF771F5B17D+39117]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF771F5E3F2+52034]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF771DA0D56+28166]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7721A8FE1+531601]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7721AE4C4+553332]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7721AE655+553733]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF771E76C40+904432]
# 	BaseThreadInitThunk [0x00007FF87B0E7034+20]
# 	RtlUserThreadStart [0x00007FF87B7A2651+33]

# %% [markdown]
# 6 - Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)
# from trak.in

# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.common.exceptions import NoSuchElementException
import time

# %%
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
# getting the web page with the provided url
url = "https://trak.in/"
driver.get(url)
time.sleep(3)
driver.maximize_window()

# %%
#  'Funding Deals' 
funding_deals = driver.find_element_by_xpath("//a[@title='http://trak.in/india-startup-funding-investment-2015/']")
funding_deals.click()

# %%
# empty lists to store data from scraping
dt=[]
name=[]
ind=[]
sv=[]
city=[]
inv=[]
invt=[]
amount=[]

# scraping the March month data
d= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-2']")
for i in d:
    dt.append(i.text)    
n= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-3']")
for i in n:
    name.append(i.text)    
x= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-4']")
for i in x:
    ind.append(i.text)    
s= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-5']")
for i in s:
    sv.append(i.text)    
c= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-6']")
for i in c:
    city.append(i.text)    
j= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-7']")
for i in j:
    inv.append(i.text)    
t= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-8']")
for i in t:
    invt.append(i.text)    
a= driver.find_elements_by_xpath("//table[@id='tablepress-56']//td[@class='column-9']")
for i in a:
    amount.append(i.text)
    
# scraping the Feb month data
d= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-2']")
for i in d:
    dt.append(i.text)    
n= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-3']")
for i in n:
    name.append(i.text)    
v= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-4']")
for i in v:
    ind.append(i.text)    
s= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-5']")
for i in s:
    sv.append(i.text)    
c= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-6']")
for i in c:
    city.append(i.text)    
j= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-7']")
for i in j:
    inv.append(i.text)    
t= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-8']")
for i in t:
    invt.append(i.text)    
a= driver.find_elements_by_xpath("//table[@id='tablepress-55']//td[@class='column-9']")
for i in a:
    amount.append(i.text)
    
# scraping the Jan month data
d= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-2']")
for i in d:
    dt.append(i.text)    
n= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-3']")
for i in n:
    name.append(i.text)    
v= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-4']")
for i in v:
    ind.append(i.text)    
s= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-5']")
for i in s:
    sv.append(i.text)    
c= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-6']")
for i in c:
    city.append(i.text)    
j= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-7']")
for i in j:
    inv.append(i.text)    
t= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-8']")
for i in t:
    invt.append(i.text)    
a= driver.find_elements_by_xpath("//table[@id='tablepress-54']//td[@class='column-9']")
for i in a:
    amount.append(i.text)    

# now creating a dataframe from all the collected information
data = list(zip(dt,name,ind,sv,city,inv,invt,amount))
df = pd.DataFrame(data, columns = ["Dates","Startup-name","Industry/Vertical","Sub-vertical","City",
                                   "Investor's Name","Investment Type","Amount"])
df
# Out:
#          Dates            Startup-name       Industry/Vertical  \
# 0   04/03/2021               DealShare              E-commerce
# 1   31/03/2021                Uniphore              Technology
# 2   30/03/2021                   Dunzo              E-commerce
# 3   30/03/2021                  BYJU’S                Edu-tech
# 4   23/03/2021             SkilloVilla                Edu-tech
# 5   25/03/2021                CityMall              E-commerce
# 6   26/03/2021                   DotPe                 FinTech
# 7   11/02/2021                Doubtnut                Edu Tech
# 8   22/02/2021                  Zomato             Hospitality
# 9   19/02/2021               Fingerlix             Hospitality
# 10  17/02/2021                   Zolve                 FinTech
# 11  15/02/2021               KreditBee                 Finance
# 12  12/02/2021               Pepperfry              E-commerce
# 13  12/02/2021                 Grofers              E-Commerce
# 14  09/02/2021                 Nothing              Technology
# 15  09/02/2021             SplashLearn                  EdTech
# 16  15/01/2021         Digit Insurance      Financial Services
# 17  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 18  19/01/2021                  DeHaat        AgriTech Startup
# 19  19/01/2021               Darwinbox                    SaaS
# 20  18/01/2021                   mfine     Health Tech Startup
# 21  18/01/2021                   Udayy                  EdTech
# 22  11/01/2021           True Elements            Food Startup
# 23  13/01/2021                   Saveo          B2B E-commerce
#
#                                          Sub-vertical               City  \
# 0                            Online shopping platform  Jaipur, Rajasthan
# 1             Conversational Service Automation (CSA)          Palo Alto
# 2                            Hyper-local delivery app          Bengaluru
# 3                                     Online tutoring          Bengaluru
# 4                 Career and job-oriented upskilling.          Bengaluru
# 5        Social ecommerce and online grocery platform            Gurgaon
# 6   Commerce and payments platform to offline ente...            Gurgaon
# 7                                 E-Learning Platform            Gurgaon
# 8                       Online Food Delivery Platform            Gurgaon
# 9                       Semi-cooked food delivery app             Mumbai
# 10                             Global Neobank Venture             Mumbai
# 11                           Digital lending platform          Bengaluru
# 12                        Multi-brand furniture brand             Mumbai
# 13                                 Online supermarket            Gurgaon
# 14                        Consumer Technology Venture             London
# 15                      Game-based learning programme            Gurgaon
# 16                                 Insurance Services          Bengaluru
# 17      Shave care, beard care, and skincare products          New Delhi
# 18  online marketplace for farm products and services              Patna
# 19                                            HR Tech             Mumbai
# 20                 AI-powered telemedicine mobile app          Bengaluru
# 21     Online learning platform for kids in class 1-5            Gurgaon
# 22                      Whole Food plant based Nashta               Pune
# 23                                         Pharmacies          Bengaluru
#
#                                       Investor's Name Investment Type  \
# 0                                     Innoven Capital  Debt Financing
# 1                           Sorenson Capital Partners        Series D
# 2                           Krishtal Advisors Pte Ltd        Series E
# 3          MC Global Edtech, B Capital, Baron, others        Series F
# 4                               Titan Capital, others            Seed
# 5                                      Accel Partners        Series A
# 6                                                PayU        Series A
# 7   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 8                                  Tiger Global, Kora         Venture
# 9            Rhodium Trust, Accel Partners and Swiggy        Series C
# 10     Accel Partners and Lightspeed Venture Partners            Seed
# 11  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 12                                    InnoVen Capital  Debt Financing
# 13                         SoftBank Vision Fund (SVF)     Unspecified
# 14                                                 GV        Series A
# 15                                       Owl Ventures        Series C
# 16   A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 17                                  Reckitt Benckiser         Venture
# 18                                    Prosus Ventures        Series C
# 19                                Salesforce Ventures            Seed
# 20                         Heritas Capital Management   Venture Round
# 21                                    Sequoia Capital    Seed Funding
# 22                              SIDBI Venture Capital          Series
# 23          Matrix Partners India, RTP Global, others            Seed
#
#           Amount
# 0    250,000,000
# 1    140,000,000
# 2      8,000,000
# 3    460,000,000
# 4    300,000,000
# 5     11,000,000
# 6     27,500,000
# 7      2,500,000
# 8    250,000,000
# 9   2,747,045.20
# 10   1,50,00,000
# 11    75,000,000
# 12     4,773,958
# 13    55,000,000
# 14    15,000,000
# 15    18,000,000
# 16   1,80,00,000
# 17  6,172,258.50
# 18    30,000,000
# 19    15,000,000
# 20    16,000,000
# 21    15,000,000
# 22   100,000,000
# 23     4,000,000

# %% [markdown]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
# getting the web page with given url
url = "https://www.digit.in/"
driver.get(url)
time.sleep(5)

# %%
driver.maximize_window()

# %%
#  searching for gaming laptops
best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# creating empty lists to store information
laptop = []
op_sys = []
display = []
processor = []
memory = []
weight = []
dimensions = []
graph_processor = []
prices = []

# fetching the laptop names
name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
for i in name:
    laptop.append(i.text)
    
# fetching information related to operating system
try:
    os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
    for i in os:
        op_sys.append(i.text)
except NoSuchElementException:
    pass

# fetching information for display
try:
    disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
    for i in disp:
        display.append(i.text)
except NoSuchElementException:
    pass

# fetching information for processor
try:
    pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
    for i in pro:
        processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for memory
try:
    mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
    for i in mem:
        memory.append(i.text)
except NoSuchElementException:
    pass

# fetching information for weight
try:
    wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
    for i in wgt:
        weight.append(i.text)
except NoSuchElementException:
    pass

# fetching information for dimensions
try:
    dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
    for i in dim:
        dimensions.append(i.text)
except NoSuchElementException:
    pass

# fetching information for graphic processor
try:
    g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
    for i in g_pro:
        graph_processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for i in price:
        prices.append(i.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# now creating a dataframe from all the collected details
data = list(zip(lap_name,op_stm,display,processor,memory,weight,dimensions,graph_processor,prices))
df = pd.DataFrame(data, columns = ["Laptop Name","Operating System","Display","Processor","Memory",
                                   "Weight(Kg)","Dimensions","Graphic-Processor","Price"])
df
# Out:
#                    Laptop Name Operating System              Display  \
# 0                 HP Victus 16       Windows 10  16.1" (1920 x 1200)
# 1                   HP Omen 15  Windows 10 Home  15.6" (1920 x 1080)
# 2                 Acer Nitro 5       Windows 10  15.6" (1920 x 1080)
# 3              MSI Stealth 15M       Windows 10  15.6" (1920 x 1080)
# 4       ASUS ROG Strix Scar 15       Windows 10  15.6" (2560 x 1440)
# 5       ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 6            ASUS ZEPHYRUS G14  Windows 10 Home    14" (1920 x 1080)
# 7             Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 8     ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# 9  Acer Aspire 7 gaming laptop  Windows 10 Home  15.6" (1920 x 1080)
#
#                                     Processor                   Memory  \
# 0          5th Gen AMD Ryzen 7 5800H | 3.2GHz  512 GB SSD/16 GBGB DDR4
# 1       AMD Ryzen 7 Octa Core-5800H | 4.4 GHz    1 TB SSD/16 GBGB DDR4
# 2             AMD Ryzen 9 Octa Core | 2.4 GHz    1 TB HDD/16 GBGB DDR4
# 3        Intel Core i7 11th Gen - 11375H | NA    1 TB SSD/16 GBGB DDR4
# 4    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz    2 TB SSD/32 GBGB DDR4
# 5               AMD Ryzen™ 9 5900HX | 3.3 GHz    1 TB SSD/16 GBGB DDR4
# 6               AMD 3rd Gen Ryzen 9 | 3.3 GHz    1 TB SSD/16 GBGB DDR4
# 7  10th Gen Intel® Core™ i5-10300H | 2.50 GHz    1 TB SSD/16 GBGB DDR4
# 8          Intel Core i7 10th Gen 10875H | NA   512 GB SSD/4 GBGB DDR4
# 9           AMD Ryzen™ 5-5500U hexa-core | NA   512 GB SSD/8 GBGB DDR4
#
#   Weight(Kg)               Dimensions              Graphic-Processor  \
# 0       2.48          37 x 26.2 x 2.4        NVIDIA GeForce RTX 3060
# 1       2.37     357.9 x 239.7 x 22.5        NVIDIA GeForce RTX 3060
# 2        2.4       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070
# 3        1.7      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060
# 4       2.30         354 x 259 x 22.6        NVIDIA GeForce RTX 3080
# 5       2.30       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070
# 6       1.65        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060
# 7        2.3  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB
# 8        2.4  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q
# 9       2.15       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650
#
#          Price
# 0  Rs  104,990
# 1  Rs  110,790
# 2  Rs  129,990
# 3  Rs  134,990
# 4  Rs  193,990
# 5  Rs  215,990
# 6  Rs  144,990
# 7   Rs  76,988
# 8  Rs  185,000
# 9   Rs  53,490

# %% [markdown]
# # 8- Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”

# %%
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
# obtaining the web page with given url
url = 'https://www.forbes.com/'
driver.get(url)
time.sleep(3)

# clicking on the hamburger option on the left side of the page
optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
optn.click()
time.sleep(1)

# now clicking on the 'Billionaires' option
bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill.click()
time.sleep(1)

# finally clicking on the 'World Billionaire' option after the mouse hover
world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
time.sleep(1)

# %%
# fetching the rank
rank = []
try:
    rnk = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rnk:
        rank.append(i.text)
except NoSuchElementException:
    pass

# fetching the names of the billionaires
names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        names.append(i.text)
except NoSuchElementException:
    pass

# fetching the total net worth
net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        net_worth.append(i.text)
except NoSuchElementException:
    pass

# fetching the age of the billionaires
Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')
    
# fetching the citizenship of the billionaires
citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        citizenship.append(i.text)
except NoSuchElementException:
    citizenship.append('-')
    
# fetching the source of incomes for the billionaires
source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
# fetching the industry in which the billionaires are prominent
industry = []
try:
    ind = driver.find_elements_by_xpath("//div[@class='category']")
    for i in ind:
        industry.append(i.text)
except NoSuchElementException:
    industry.append('-')
    
# now creating a dataframe from all the collected information
data = list(zip(rank,names,net_worth,Age,citizenship,source,industry))
df = pd.DataFrame(data, columns = ["Rank", "Name", "Net worth", "Age", "Citizenship", "Source","Industry"])
df
# Out:
#      Rank                      Name Net worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver = webdriver.Edge(executable_path = 'D:\Brijesh\Internship\edgedriver_win64\\msedgedriver.exe')

# %%
# obtaining the web page with given url
url = "https://www.youtube.com/"
driver.get(url)

# search option on youtube
search = driver.find_element_by_id('search')

# %%
# get input from the user
item = str(input("Enter what you want to search on YouTube: "))
search.send_keys(item)

# clicking on search button
search_btn = driver.find_element_by_xpath("//button[@id='search-icon-legacy']")
search_btn.click()
time.sleep(3)

# now we will click on the YT video
video = driver.find_element_by_xpath("//a[@id='video-title']").click()
time.sleep(10)
# Out:
# Enter what you want to search on YouTube: data science
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-54-a2c2fafafb34> in <module>
#       1 # get input from the user
#       2 item = str(input("Enter what you want to search on YouTube: "))
# ----> 3 search.send_keys(item)
#       4
#       5 # clicking on search button
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     538                 value = '\n'.join(remote_files)
#     539
# --> 540         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     541                       {'text': "".join(keys_to_typing(value)),
#     542                        'value': keys_to_typing(value)})
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: MicrosoftEdge=99.0.1150.36)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::unpack [0x00007FF7E75C3A82+22610]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7E7502352+503810]
# 	Ordinal0 [0x00007FF7E7000E5B+659035]
# 	Ordinal0 [0x00007FF7E70360A3+876707]
# 	Ordinal0 [0x00007FF7E7035473+873587]
# 	Ordinal0 [0x00007FF7E705703A+1011770]
# 	Ordinal0 [0x00007FF7E702FC74+851060]
# 	Ordinal0 [0x00007FF7E7057350+1012560]
# 	Ordinal0 [0x00007FF7E706B8A4+1095844]
# 	Ordinal0 [0x00007FF7E7056E53+1011283]
# 	Ordinal0 [0x00007FF7E702E0C7+843975]
# 	Ordinal0 [0x00007FF7E702F598+849304]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7E71C91B8+848488]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7E72BB17D+39117]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7E72BE3F2+52034]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7E7100D56+28166]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7E7508FE1+531601]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7E750E4C4+553332]
# 	Microsoft::Applications::Events::time_ticks_t::time_ticks_t [0x00007FF7E750E655+553733]
# 	Microsoft::Applications::Events::EventProperty::to_string [0x00007FF7E71D6C40+904432]
# 	BaseThreadInitThunk [0x00007FF87B0E7034+20]
# 	RtlUserThreadStart [0x00007FF87B7A2651+33]
